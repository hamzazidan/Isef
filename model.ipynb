# %% [markdown]
# # Getting the apikey from a full dataset on roboflow

# %% [markdown]
# ![roboflow.png](attachment:roboflow.png)

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# d:\AI

# %% [markdown]
# # Downloading ultralytics library for training a yolo model

# %%
# !pip install ultralytics==8.0.196

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196  Python-3.11.5 torch-2.1.2+cpu CPU (11th Gen Intel Core(TM) i7-1165G7 2.80GHz)
# Setup complete  (8 CPUs, 15.8 GB RAM, 1.6/9.8 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# # Importing the dataset from roboflow using the apikey

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow --quiet

from roboflow import Roboflow
rf = Roboflow(api_key="YOUR_API_KEY")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
dataset = project.version(1).download("yolov8")

# %% [markdown]
# ![apikeycolab.png](attachment:apikeycolab.png)

# %% [markdown]
# # Start Training the model

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=25 imgsz=800 plots=True

# %% [markdown]
# ![custom_training.png](attachment:custom_training.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Showing the graph to know the performance of the model

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/confusion_matrix.png', width=600)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Showing the mean average precision mAP

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/results.png', width=600)

# %% [markdown]
# ![image.png](attachment:image.png)
